# %% [markdown]
# ## Prepare Data

# %%
# Import our dependencies
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
#read the csv
ML_Data= pd.read_csv('Data/Five_Year_Data.csv')
ML_Data.head()
# Out:
#            GEO_ID  Below_9th_grade  9_12th_grade  High_School_Grad
# 0  0500000US01001              2.6           8.7              32.6  \
# 1  0500000US01003              2.7           7.0              27.6
# 2  0500000US01005              8.2          18.8              35.7
# 3  0500000US01007              5.7          11.1              47.3
# 4  0500000US01009              7.5          12.4              34.0
#
#    Some_College  Associate's_degree  Bachelor's_degree  Graduate_degree
# 0          20.3                 8.1               15.9             11.8  \
# 1          22.0                 9.4               20.7             10.6
# 2          18.1                 7.0                7.8              4.4
# 3          18.6                 5.8                7.6              3.9
# 4          21.4                12.0                8.1              4.5
#
#    Population (16+)  Employed  ...  Total Population  White  Black
# 0           43368.0   24124.0  ...             55200   76.9   19.1  \
# 1          167712.0   93379.0  ...            208107   86.3    9.5
# 2           20948.0    8720.0  ...             25782   47.4   47.6
# 3           18470.0    8099.0  ...             22527   76.7   22.3
# 4           45915.0   21346.0  ...             57645   95.5    1.5
#
#    American Indian  Asian  Pacific Islander  Hispanic/Latino          County
# 0              0.3    1.0               0.1              2.8  Autauga County  \
# 1              0.7    0.8               0.0              4.5  Baldwin County
# 2              0.3    0.4               0.0              4.3  Barbour County
# 3              0.0    0.2               0.0              2.4     Bibb County
# 4              0.2    0.3               0.0              9.1   Blount County
#
#      State  Year
# 0  Alabama  2018
# 1  Alabama  2018
# 2  Alabama  2018
# 3  Alabama  2018
# 4  Alabama  2018
#
# [5 rows x 37 columns]

# %%
ML_Data.columns
# Out:
# Index(['GEO_ID', 'Below_9th_grade', '9_12th_grade', 'High_School_Grad',
#        'Some_College', 'Associate's_degree', 'Bachelor's_degree',
#        'Graduate_degree', 'Population (16+)', 'Employed',
#        'Median Household Income', 'Per capita Income', 'Unemployment Rate',
#        'Professional (Occupation)', 'Service (Occupation)',
#        'Sales (Occupation)', 'Construction (Occupation)',
#        'Production (Occupation)', 'Salary (Class)', 'Gov't (Class)',
#        'Self-employed (Class)', 'Fam-unpaid (Class)', 'Poverty',
#        'Child-poverty', 'Median Home value', 'Median Mortgage', 'Median Rent',
#        'Total Population', 'White', 'Black', 'American Indian', 'Asian',
#        'Pacific Islander', 'Hispanic/Latino', 'County', 'State', 'Year'],
#       dtype='object')

# %%
## Data that has been tested
# All data excluding State, County, Year, Geo_ID: R2 Score: 0.930
# education level data to poverty rate:  R2 Score: 0.568
# Occupation Data to Poverty rate: R2 Score: 0.294
# Occupation and class data to poverty rate: R2 Score: 0.501
# Income and property data to poverty rate: R2 Score: 0.749 highly correlated data
# Demographic Data to poverty rate: R2 Score: 0.575
# education, Occupation, and Demographic to poverty rate: R2 Score: 0.751 high MSE of 9

## Highly Correlated data to avoid redundancy removed: 
# Child -Poverty,Median Mortgage, Median Rent, Per Capita Income, Employed/Popultion 16+


#Model Data to test
# 'Median Household Income', 'Per capita Income','Median Home value', 'Median Mortgage', 'Median Rent'
Poverty_data= ML_Data[['Below_9th_grade', '9_12th_grade', 'High_School_Grad',
       'Some_College', "Associate's_degree", "Bachelor's_degree",
       'Graduate_degree', 'Population (16+)',
       'Median Household Income', 'Unemployment Rate',
       'Professional (Occupation)', 'Service (Occupation)',
       'Sales (Occupation)', 'Construction (Occupation)',
       'Production (Occupation)', 'Salary (Class)', "Gov't (Class)",
       'Self-employed (Class)', 'Fam-unpaid (Class)', 'Poverty',
       'Median Home value',
       'White', 'Black', 'American Indian', 'Asian',
       'Pacific Islander', 'Hispanic/Latino']]
Poverty_data.head()
# Out:
#    Below_9th_grade  9_12th_grade  High_School_Grad  Some_College
# 0              2.6           8.7              32.6          20.3  \
# 1              2.7           7.0              27.6          22.0
# 2              8.2          18.8              35.7          18.1
# 3              5.7          11.1              47.3          18.6
# 4              7.5          12.4              34.0          21.4
#
#    Associate's_degree  Bachelor's_degree  Graduate_degree  Population (16+)
# 0                 8.1               15.9             11.8           43368.0  \
# 1                 9.4               20.7             10.6          167712.0
# 2                 7.0                7.8              4.4           20948.0
# 3                 5.8                7.6              3.9           18470.0
# 4                12.0                8.1              4.5           45915.0
#
#    Median Household Income  Unemployment Rate  ...  Self-employed (Class)
# 0                  58786.0                4.2  ...                    5.6  \
# 1                  55962.0                4.4  ...                    6.7
# 2                  34186.0                9.5  ...                    5.7
# 3                  45340.0                7.5  ...                    5.5
# 4                  48695.0                4.1  ...                    4.8
#
#    Fam-unpaid (Class)  Poverty  Median Home value  White  Black
# 0                 0.1     15.4           147900.0   76.9   19.1  \
# 1                 0.1     10.6           189800.0   86.3    9.5
# 2                 0.2     28.9            92900.0   47.4   47.6
# 3                 0.7     14.0            96500.0   76.7   22.3
# 4                 0.2     14.4           124700.0   95.5    1.5
#
#    American Indian  Asian  Pacific Islander  Hispanic/Latino
# 0              0.3    1.0               0.1              2.8
# 1              0.7    0.8               0.0              4.5
# 2              0.3    0.4               0.0              4.3
# 3              0.0    0.2               0.0              2.4
# 4              0.2    0.3               0.0              9.1
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data Exploration and Analysis

# %%
# Calculate the correlation matrix
#https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
#chatgpt for aid on plotting
correlation = Poverty_data.corr()

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sb.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Random Forest Model

# %%
# Split target column and Features Columns
y = Poverty_data['Poverty']
X = Poverty_data.drop(columns='Poverty')

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create scaler instance
scaler = StandardScaler()
# Fit the Standardscaler with training data
scaler.fit(X_train)
# Scale the training data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# * Fitting the Random Forest Model

# %%
# Create the random forest Regressor instance
rf_model = RandomForestRegressor(n_estimators=500, random_state=78)

# %%
# Fit the model and use .ravel()on the "y_train" data. 
rf_model = rf_model.fit(X_train_scaled, y_train.ravel())

# %% [markdown]
# - Making Predictions Using the Random Forest Model

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# ## Model Evaluation

# %%
# Import relevant metrics from scikit-learn
from sklearn.metrics import mean_squared_error, r2_score

# Compute metrics for the linear regression model: score, r2, mse, rmse, std
score = rf_model.score(X, y, sample_weight=None)
r2 = r2_score(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
std = np.std(y)

# Print relevant metrics.
print(f"The score is {score}.")
print(f"The r2 is {r2}.")
print(f"The mean squared error is {mse}.")
print(f"The root mean squared error is {rmse}.")
print(f"The standard deviation is {std}.")
# Out:
# /Users/gcarmona/anaconda3/envs/dev/lib/python3.10/site-packages/sklearn/base.py:457: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# The score is -0.38826999073137913.
# The r2 is 0.8408519376902999.
# The mean squared error is 6.173497645201841.
# The root mean squared error is 2.4846524193942785.
# The standard deviation is 6.220438667941329.

# %%
# Visualize the distribution of the target variable
sb.histplot(y_train, kde=True, label='Train')
sb.histplot(y_test, kde=True, label='Test', color='red')
plt.legend()
plt.title('Distribution of Target Variable (Poverty Rate)')
plt.show()

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.6663143603990235, 'Median Household Income'),
#  (0.07491126015161634, 'White'),
#  (0.02392565974723758, 'Unemployment Rate'),
#  (0.021156466392952652, 'American Indian'),
#  (0.020971289403332892, 'Salary (Class)'),
#  (0.020221792639173914, 'Population (16+)'),
#  (0.012641374160011178, "Bachelor's_degree"),
#  (0.011673135118893995, 'Hispanic/Latino'),
#  (0.010972073591124372, 'Professional (Occupation)'),
#  (0.01064296723788971, 'Median Home value'),
#  (0.0105450737251057, 'Service (Occupation)'),
#  (0.01018574232678858, '9_12th_grade'),
#  (0.009950613999808719, 'Construction (Occupation)'),
#  (0.009925130347220923, 'Self-employed (Class)'),
#  (0.008874719085166847, 'Production (Occupation)'),
#  (0.008854833918282914, 'Graduate_degree'),
#  (0.008698230163829212, "Gov't (Class)"),
#  (0.008514466971923023, 'Sales (Occupation)'),
#  (0.00829041908335845, 'Black'),
#  (0.008012992744031847, 'High_School_Grad'),
#  (0.007926223943694837, 'Below_9th_grade'),
#  (0.006983370904264956, 'Asian'),
#  (0.00683723041936703, 'Some_College'),
#  (0.006822868924392155, "Associate's_degree"),
#  (0.004265783970627136, 'Fam-unpaid (Class)'),
#  (0.0018819206308817139, 'Pacific Islander')]
